# %% [markdown]
# # House Price Prediction Using Linear Regression

# %% [markdown]
# # Business Problem
#
#
# Business problem is very simple, There is a construction company who wants to Know the Price for respective house and flats,Based on Area and the facility provided by them.

# %% [markdown]
# # Data
#
# We have 545 rows with 12 features and 1 target variable,Every row provides us with Data of a house with Price,Area and various
# facilities provided by it.

# %% [markdown]
# # Machine Learning Problem
#
#
# So Converting a Business problem to a Machine Learning problem, This seems to be a simple binary classification problem in which we have 2 classes, "yes" and "no".
#
# We have some numerical features, some categorical features.

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
df = pd.read_csv("Housing.csv")

# %% [markdown]
# # Understanding Data And Manipulation

# %%
#we are given with a Data set below
import pandas as pd
df = pd.read_csv("Housing.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
print(display(df))
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
print("Number of data points:",df.shape[0])
print("Number of features:",df.shape[1])
print("Features:",df.columns.values)
#below are the feature values to be used
# Out:
# Number of data points: 545
# Number of features: 13
# Features: ['price' 'area' 'bedrooms' 'bathrooms' 'stories' 'mainroad' 'guestroom'
#  'basement' 'hotwaterheating' 'airconditioning' 'parking' 'prefarea'
#  'furnishingstatus']

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# # Observation

# %%
duplicate=df[df.duplicated()]
duplicate.head()
# Out:
# Empty DataFrame
# Columns: [price, area, bedrooms, bathrooms, stories, mainroad, guestroom, basement, hotwaterheating, airconditioning, parking, prefarea, furnishingstatus]
# Index: []

# %%
df["price"].value_counts()
# Out:
# 3500000     17
# 4200000     17
# 4900000     12
# 3150000      9
# 5600000      9
#             ..
# 6580000      1
# 4319000      1
# 4375000      1
# 4382000      1
# 13300000     1
# Name: price, Length: 219, dtype: int64

# %%
df["mainroad"].value_counts()
# Out:
# yes    468
# no      77
# Name: mainroad, dtype: int64

# %%
df["prefarea"].value_counts()
# Out:
# no     417
# yes    128
# Name: prefarea, dtype: int64

# %%
df["airconditioning"].value_counts()
# Out:
# no     373
# yes    172
# Name: airconditioning, dtype: int64

# %%
df["parking"].value_counts()
# Out:
# 0    299
# 1    126
# 2    108
# 3     12
# Name: parking, dtype: int64

# %%
import matplotlib.pyplot as plt
guestroom_count=df['guestroom'].value_counts()
print(guestroom_count)

plt.figure(figsize=(8,6))
plt.hist(df['guestroom'],facecolor='g')
plt.show()
# Out:
# no     448
# yes     97
# Name: guestroom, dtype: int64

# %% [markdown]
# #
# It seems that data is imbalanced, as number of "yes" is 97 and number of "no" is 448, we will balanced the data with upsampling.

# %%
import matplotlib.pyplot as plt
x=df['area']
y=df['price']

plt.scatter(y,x)
plt.show()

# %% [markdown]
#  we will be scaling the faeture Valueusing standard scaler

# %%
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
categories=['mainroad','guestroom','basement','hotwaterheating','airconditioning','prefarea','furnishingstatus']
df=pd.get_dummies(df,columns=categories,drop_first=True)

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories  parking  mainroad_yes  \
# 0    13300000  7420         4          2        3        2             1
# 1    12250000  8960         4          4        4        3             1
# 2    12250000  9960         3          2        2        2             1
# 3    12215000  7500         4          2        2        3             1
# 4    11410000  7420         4          1        2        2             1
# ..        ...   ...       ...        ...      ...      ...           ...
# 540   1820000  3000         2          1        1        2             1
# 541   1767150  2400         3          1        1        0             0
# 542   1750000  3620         2          1        1        0             1
# 543   1750000  2910         3          1        1        0             0
# 544   1750000  3850         3          1        2        0             1
#
#      guestroom_yes  basement_yes  hotwaterheating_yes  airconditioning_yes  \
# ...

# %%
from sklearn.preprocessing import StandardScaler 
scale=StandardScaler()
area1=scale.fit_transform(df[['area']])
df['area']=area1

# %%
df
# Out:
#         price      area  bedrooms  bathrooms  stories  parking  mainroad_yes  \
# 0    13300000  1.046726         4          2        3        2             1
# 1    12250000  1.757010         4          4        4        3             1
# 2    12250000  2.218232         3          2        2        2             1
# 3    12215000  1.083624         4          2        2        3             1
# 4    11410000  1.046726         4          1        2        2             1
# ..        ...       ...       ...        ...      ...      ...           ...
# 540   1820000 -0.991879         2          1        1        2             1
# 541   1767150 -1.268613         3          1        1        0             0
# 542   1750000 -0.705921         2          1        1        0             1
# 543   1750000 -1.033389         3          1        1        0             0
# 544   1750000 -0.599839         3          1        2        0             1
#
# ...

# %%
x=df.drop(['price'],axis=1)

# %%
x
# Out:
#          area  bedrooms  bathrooms  stories  parking  mainroad_yes  \
# 0    1.046726         4          2        3        2             1
# 1    1.757010         4          4        4        3             1
# 2    2.218232         3          2        2        2             1
# 3    1.083624         4          2        2        3             1
# 4    1.046726         4          1        2        2             1
# ..        ...       ...        ...      ...      ...           ...
# 540 -0.991879         2          1        1        2             1
# 541 -1.268613         3          1        1        0             0
# 542 -0.705921         2          1        1        0             1
# 543 -1.033389         3          1        1        0             0
# 544 -0.599839         3          1        2        0             1
#
#      guestroom_yes  basement_yes  hotwaterheating_yes  airconditioning_yes  \
# 0                0             0                    0                    1
# ...

# %%
y=df['price']

# %%
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=50)

# %%
X_train
# Out:
#          area  bedrooms  bathrooms  stories  parking  mainroad_yes  \
# 339 -0.908859         4          2        2        0             1
# 63   0.557830         4          2        3        2             1
# 158  1.305011         3          1        1        2             1
# 203  0.115056         4          1        2        0             1
# 482 -0.922695         3          1        2        0             0
# ..        ...       ...        ...      ...      ...           ...
# 70  -0.530656         3          2        2        0             1
# 132  0.022811         3          1        3        0             1
# 289  0.322606         2          1        1        2             1
# 109  0.675442         4          2        2        1             1
# 480 -0.770492         3          1        2        1             0
#
#      guestroom_yes  basement_yes  hotwaterheating_yes  airconditioning_yes  \
# 339              0             0                    0                    0
# ...

# %%
X_test
# Out:
#          area  bedrooms  bathrooms  stories  parking  mainroad_yes  \
# 333 -0.991879         3          1        2        0             1
# 37   1.775458         4          2        4        2             1
# 396 -0.696696         2          1        1        1             1
# 494  0.760768         2          1        1        0             1
# 536 -0.798165         5          1        2        0             0
# ..        ...       ...        ...      ...      ...           ...
# 284  1.208154         2          1        1        1             1
# 246 -0.752043         3          1        1        0             1
# 352  0.313382         2          1        1        2             1
# 512 -0.991879         2          1        2        0             1
# 463 -0.950369         2          1        1        0             1
#
#      guestroom_yes  basement_yes  hotwaterheating_yes  airconditioning_yes  \
# 333              0             0                    0                    0
# ...

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
Lrmodel=LinearRegression()
Lrmodel.fit(X_train,y_train)


y_train_predict=Lrmodel.predict(X_train)
y_test_predict=Lrmodel.predict(X_test)
from sklearn.metrics import r2_score

#for training data
r2_score(y_train,y_train_predict)
# Out:
# 0.671832588253032

# %%
#for testing data
r2_score(y_test,y_test_predict)
# Out:
# 0.6914395374406818
